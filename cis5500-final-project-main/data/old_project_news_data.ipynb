# %%
# !pip install newsapi-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from urllib.request import urlopen, Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from newsapi import NewsApiClient
from datetime import date, timedelta

# %%
df = pd.read_csv('df_stock_info.csv')

# %%
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]
df.to_csv('S&P500-Info.csv')
df.to_csv("S&P500-Symbols.csv", columns=['Symbol'])
symbol_list = df['Symbol'].tolist()

#https://medium.com/wealthy-bytes/5-lines-of-python-to-automate-getting-the-s-p-500-95a632e5e567
# Out:
# 503

# %%
news_dict = {}
news_dict['Company'] = []
news_dict['Source'] = []
news_dict['Author'] = []
news_dict['Title'] = []
news_dict['URL'] = []
news_dict['Publish_Date'] = []

# %%
# %%time
for company in symbol_list:
  print('company', company)
  phrase = '{} stock'.format(company)
  newsapi = NewsApiClient(api_key='f22df238143b4f1697ba268619ee1e76')
  my_date = date.today() - timedelta(days = 7)
  articles = newsapi.get_everything(q=phrase,
                                  from_param = my_date.isoformat(),
                                  language="en",
                                  sort_by="relevancy",
                                  page_size = 5)

  for i in range(len(articles['articles'])):
    news_dict['Company'].append(company)
    news_dict['Source'].append(articles['articles'][i]['source']['name'])
    news_dict['Author'].append(articles['articles'][i]['author'])
    news_dict['Title'].append(articles['articles'][i]['title'])
    news_dict['URL'].append(articles['articles'][i]['url'])
    news_dict['Publish_Date'].append(articles['articles'][i]['publishedAt'])
# Out:
# company 3M
# company A. O. Smith
# company Abbott
# company AbbVie
# company Accenture
# company Activision Blizzard
# company ADM
# company Adobe Inc.
# company ADP
# company Advance Auto Parts
# company AES Corporation
# company Aflac
# company Agilent Technologies
# company Air Products and Chemicals
# company Akamai
# company Alaska Air Group
# company Albemarle Corporation
# company Alexandria Real Estate Equities
# company Align Technology
# company Allegion
# company Alliant Energy
# company Allstate
# company Alphabet Inc. (Class A)
# company Alphabet Inc. (Class C)
# company Altria
# company Amazon
# company Amcor
# company AMD
# company Ameren
# company American Airlines Group
# company American Electric Power
# company American Express
# company American International Group
# company American Tower
# company American Water Works
# company Ameriprise Financial
# company AmerisourceBergen
# company Ametek
# company Amgen
# company Amphenol
# company Analog Devices
# ...

# %%
df_news = pd.DataFrame.from_dict(news_dict)
df_news
# Out:
#         Company               Source  \
# 0            3M         The Guardian
# 1            3M          Motley Fool
# 2            3M               Forbes
# 3            3M          Motley Fool
# 4            3M          Motley Fool
# ..          ...                  ...
# 395  CBRE Group   Marketscreener.com
# 396  CBRE Group   Marketscreener.com
# 397  CBRE Group   Marketscreener.com
# 398         CDW   Marketscreener.com
# 399    Celanese  Yahoo Entertainment
#
#                                                 Author  \
# 0                                           Steve Rose
# 1               newsfeedback@fool.com (Keith Speights)
# 2    Trefis Team, Contributor, \n Trefis Team, Cont...
# 3                   newsfeedback@fool.com (Lee Samaha)
# 4    newsfeedback@fool.com (Daniel Foelber, Scott L...
# ..                                                 ...
# 395                                     MarketScreener
# 396                                     MarketScreener
# ...

# %%
from google.colab import files

df_news.to_csv('df_news1.csv')
files.download('df_news1.csv')

# %%
pd.DataFrame.from_dict(articles['articles'][0])
# Out:
#                 source                           author  \
# id    business-insider  jsor@insider.com (Jennifer Sor)
# name  Business Insider  jsor@insider.com (Jennifer Sor)
#
#                                                   title  \
# id    Apple will be the safest tech stock over the n...
# name  Apple will be the safest tech stock over the n...
#
#                                             description  \
# id    "Apple is still doing probably the best job of...
# name  "Apple is still doing probably the best job of...
#
#                                                     url  \
# id    https://markets.businessinsider.com/news/stock...
# name  https://markets.businessinsider.com/news/stock...
#
#                                              urlToImage           publishedAt  \
# id    https://i.insider.com/62bebd5f9b16eb00180206db...  2023-03-15T16:33:02Z
# name  https://i.insider.com/62bebd5f9b16eb00180206db...  2023-03-15T16:33:02Z
#
# ...

# %%
updated_df = df.Security.unique()[99:len(symbol_list)]

# %%
updated_df

# %%
news_dict1 = {}
news_dict1['Company'] = []
news_dict1['Source'] = []
news_dict1['Author'] = []
news_dict1['Title'] = []
news_dict1['URL'] = []
news_dict1['Publish_Date'] = []

# %%
# %%time
for company in updated_df:
  print('company', company)
  phrase = '{} stock'.format(company)
  newsapi = NewsApiClient(api_key='a6c2040c24ac454c9ee0bef374abda04')
  my_date = date.today() - timedelta(days = 7)
  articles = newsapi.get_everything(q=phrase,
                                  from_param = my_date.isoformat(),
                                  language="en",
                                  sort_by="relevancy",
                                  page_size = 3)

  for i in range(len(articles['articles'])):
    news_dict1['Company'].append(company)
    news_dict1['Source'].append(articles['articles'][i]['source']['name'])
    news_dict1['Author'].append(articles['articles'][i]['author'])
    news_dict1['Title'].append(articles['articles'][i]['title'])
    news_dict1['URL'].append(articles['articles'][i]['url'])
    news_dict1['Publish_Date'].append(articles['articles'][i]['publishedAt'])
# Out:
# company CenterPoint Energy
# company Ceridian
# company CF Industries
# company Charles River Laboratories
# company Charles Schwab Corporation
# company Charter Communications
# company Chevron Corporation
# company Chipotle Mexican Grill
# company Chubb Limited
# company Church & Dwight
# company Cigna
# company Cincinnati Financial
# company Cintas
# company Cisco
# company Citigroup
# company Citizens Financial Group
# company Clorox
# company CME Group
# company CMS Energy
# company Coca-Cola Company (The)
# company Cognizant
# company Colgate-Palmolive
# company Comcast
# company Comerica
# company Conagra Brands
# company ConocoPhillips
# company Consolidated Edison
# company Constellation Brands
# company Constellation Energy
# company CooperCompanies
# company Copart
# company Corning Inc.
# company Corteva
# company CoStar Group
# company Costco
# company Coterra
# company Crown Castle
# company CSX
# company Cummins
# company CVS Health
# company D.R. Horton
# ...

# %%
df_news1 = pd.DataFrame.from_dict(news_dict1)
df_news1
# Out:
#                  Company               Source  \
# 0     CenterPoint Energy  Yahoo Entertainment
# 1     CenterPoint Energy   Marketscreener.com
# 2     CenterPoint Energy   Marketscreener.com
# 3          CF Industries          Motley Fool
# 4          CF Industries          Motley Fool
# ..                   ...                  ...
# 253     Fifth Third Bank          MarketWatch
# 254     Fifth Third Bank       Netinterest.co
# 255  First Republic Bank     Business Insider
# 256  First Republic Bank     Business Insider
# 257  First Republic Bank     Business Insider
#
#                                                 Author  \
# 0                                          PR Newswire
# 1                                       MarketScreener
# 2                                       MarketScreener
# 3    newsfeedback@fool.com (Jason Hall and Tyler Cr...
# 4               newsfeedback@fool.com (Keith Speights)
# ..                                                 ...
# ...

# %%
df_news_updated = pd.concat([df_news,df_news1])

# %%
from google.colab import files

df_news_updated.to_csv('df_news_updated.csv')
files.download('df_news_updated.csv')

# %%
updated_df1 = df.Security.unique()[200:len(symbol_list)]

# %%
news_dict2 = {}
news_dict2['Company'] = []
news_dict2['Source'] = []
news_dict2['Author'] = []
news_dict2['Title'] = []
news_dict2['URL'] = []
news_dict2['Publish_Date'] = []

# %%
# %%time
for company in updated_df1:
  print('company', company)
  phrase = '{} stock'.format(company)
  newsapi = NewsApiClient(api_key='db0e9f67601646c698cc3a399bce081e')
  my_date = date.today() - timedelta(days = 7)
  articles = newsapi.get_everything(q=phrase,
                                  from_param = my_date.isoformat(),
                                  language="en",
                                  sort_by="relevancy",
                                  page_size = 3)

  for i in range(len(articles['articles'])):
    news_dict1['Company'].append(company)
    news_dict1['Source'].append(articles['articles'][i]['source']['name'])
    news_dict1['Author'].append(articles['articles'][i]['author'])
    news_dict1['Title'].append(articles['articles'][i]['title'])
    news_dict1['URL'].append(articles['articles'][i]['url'])
    news_dict1['Publish_Date'].append(articles['articles'][i]['publishedAt'])
# Out:
# company FirstEnergy
# company FIS
# company Fiserv
# company Fleetcor
# company FMC Corporation
# company Ford Motor Company
# company Fortinet
# company Fortive
# company Fox Corporation (Class A)
# company Fox Corporation (Class B)
# company Franklin Templeton
# company Freeport-McMoRan
# company Garmin
# company Gartner
# company GE HealthCare
# company Gen Digital
# company Generac
# company General Dynamics
# company General Electric
# company General Mills
# company General Motors
# company Genuine Parts Company
# company Gilead Sciences
# company Globe Life
# company Global Payments
# company Goldman Sachs
# company Halliburton
# company Hartford (The)
# company Hasbro
# company HCA Healthcare
# company Healthpeak
# company Henry Schein
# company Hershey's
# company Hess Corporation
# company Hewlett Packard Enterprise
# company Hilton Worldwide
# company Hologic
# company Home Depot (The)
# company Honeywell
# company Hormel Foods
# company Host Hotels & Resorts
# ...

# %%
df_news2 = pd.DataFrame.from_dict(news_dict1)
df_news2
# Out:
#                 Company                     Source  \
# 0    CenterPoint Energy        Yahoo Entertainment
# 1    CenterPoint Energy         Marketscreener.com
# 2    CenterPoint Energy         Marketscreener.com
# 3         CF Industries                Motley Fool
# 4         CF Industries                Motley Fool
# ..                  ...                        ...
# 515            M&T Bank                Motley Fool
# 516            M&T Bank                 Nature.com
# 517        Marathon Oil  Investor's Business Daily
# 518        Marathon Oil        Yahoo Entertainment
# 519        Marathon Oil        Yahoo Entertainment
#
#                                                 Author  \
# 0                                          PR Newswire
# 1                                       MarketScreener
# 2                                       MarketScreener
# 3    newsfeedback@fool.com (Jason Hall and Tyler Cr...
# 4               newsfeedback@fool.com (Keith Speights)
# ...

# %%
df_news_updated = pd.concat([df_news,df_news2])

# %%
df_news_updated

# %%
from google.colab import files

df_news_updated.to_csv('df_news_updated.csv')
files.download('df_news_updated.csv')

# %%
updated_df2 = df.Security.unique()[300:len(symbol_list)]

# %%
news_dict3 = {}
news_dict3['Company'] = []
news_dict3['Source'] = []
news_dict3['Author'] = []
news_dict3['Title'] = []
news_dict3['URL'] = []
news_dict3['Publish_Date'] = []

# %%
# %%time
for company in updated_df2:
  print('company', company)
  phrase = '{} stock'.format(company)
  newsapi = NewsApiClient(api_key='80bd8b86dc8f46b3a97c10e02d18cd32')
  my_date = date.today() - timedelta(days = 7)
  articles = newsapi.get_everything(q=phrase,
                                  from_param = my_date.isoformat(),
                                  language="en",
                                  sort_by="relevancy",
                                  page_size = 3)

  for i in range(len(articles['articles'])):
    news_dict3['Company'].append(company)
    news_dict3['Source'].append(articles['articles'][i]['source']['name'])
    news_dict3['Author'].append(articles['articles'][i]['author'])
    news_dict3['Title'].append(articles['articles'][i]['title'])
    news_dict3['URL'].append(articles['articles'][i]['url'])
    news_dict3['Publish_Date'].append(articles['articles'][i]['publishedAt'])
# Out:
# company Marathon Petroleum
# company MarketAxess
# company Marriott International
# company Marsh McLennan
# company Martin Marietta Materials
# company Masco
# company Mastercard
# company Match Group
# company McCormick & Company
# company McDonald's
# company McKesson
# company Medtronic
# company Merck & Co.
# company Meta Platforms
# company MetLife
# company Mettler Toledo
# company MGM Resorts
# company Microchip Technology
# company Micron Technology
# company Microsoft
# company Mid-America Apartment Communities
# company Moderna
# company Mohawk Industries
# company Molina Healthcare
# company Molson Coors Beverage Company
# company Mondelez International
# company Monolithic Power Systems
# company Monster Beverage
# company Moody's Corporation
# company Morgan Stanley
# company Mosaic Company (The)
# company Motorola Solutions
# company MSCI
# company Nasdaq, Inc.
# company NetApp
# company Netflix
# company Newell Brands
# company Newmont
# company News Corp (Class A)
# ...

# %%
df_news3 = pd.DataFrame.from_dict(news_dict3)
df_news3
# Out:
#                    Company                     Source  \
# 0       Marathon Petroleum                MarketWatch
# 1       Marathon Petroleum        Yahoo Entertainment
# 2       Marathon Petroleum  Investor's Business Daily
# 3              MarketAxess                MarketWatch
# 4              MarketAxess                 Biztoc.com
# ..                     ...                        ...
# 260  Raytheon Technologies                Motley Fool
# 261  Raytheon Technologies        Yahoo Entertainment
# 262          Realty Income                Motley Fool
# 263          Realty Income                Motley Fool
# 264          Realty Income                Motley Fool
#
#                                                 Author  \
# 0                                         Tomi Kilgore
# 1                                             TipRanks
# 2                            Investor's Business Daily
# 3                                       Joy Wiltermuth
# ...

# %%
df_news_updated = pd.concat([df_news,df_news2, df_news3])
df_news_updated

# %%
from google.colab import files

df_news_updated.to_csv('df_news_updated.csv')
files.download('df_news_updated.csv')

# %%
df_updated3 = df.Security.unique()[399:len(symbol_list)]

# %%
df_updated3

# %%
news_dict4 = {}
news_dict4['Company'] = []
news_dict4['Source'] = []
news_dict4['Author'] = []
news_dict4['Title'] = []
news_dict4['URL'] = []
news_dict4['Publish_Date'] = []

# %%
# %%time
for company in df_updated3:
  print('company', company)
  phrase = '{} stock'.format(company)
  newsapi = NewsApiClient(api_key='19876ea5950c41bb91748de3d96d6222')
  my_date = date.today() - timedelta(days = 7)
  articles = newsapi.get_everything(q=phrase,
                                  from_param = my_date.isoformat(),
                                  language="en",
                                  sort_by="relevancy",
                                  page_size = 3)

  for i in range(len(articles['articles'])):
    news_dict4['Company'].append(company)
    news_dict4['Source'].append(articles['articles'][i]['source']['name'])
    news_dict4['Author'].append(articles['articles'][i]['author'])
    news_dict4['Title'].append(articles['articles'][i]['title'])
    news_dict4['URL'].append(articles['articles'][i]['url'])
    news_dict4['Publish_Date'].append(articles['articles'][i]['publishedAt'])
# Out:
# company Regency Centers
# company Regeneron
# company Regions Financial Corporation
# company Republic Services
# company ResMed
# company Robert Half
# company Rockwell Automation
# company Rollins, Inc.
# company Roper Technologies
# company Ross Stores
# company Royal Caribbean Group
# company S&P Global
# company Salesforce
# company SBA Communications
# company Schlumberger
# company Seagate Technology
# company Sealed Air
# company Sempra Energy
# company ServiceNow
# company Sherwin-Williams
# company Simon Property Group
# company Skyworks Solutions
# company J.M. Smucker Company (The)
# company Snap-on
# company SolarEdge
# company Southern Company
# company Southwest Airlines
# company Stanley Black & Decker
# company Starbucks
# company State Street Corporation
# company Steel Dynamics
# company Steris
# company Stryker Corporation
# company Synchrony Financial
# company Synopsys
# company Sysco
# company T-Mobile US
# company T. Rowe Price
# company Take-Two Interactive
# ...

# %%
df_news4 = pd.DataFrame.from_dict(news_dict4)
df_news4

# %%
df_news_updated = pd.concat([df_news,df_news2, df_news3, df_news4])
df_news_updated
# Out:
#          Company               Source  \
# 0             3M         The Guardian
# 1             3M          Motley Fool
# 2             3M               Forbes
# 3             3M          Motley Fool
# 4             3M          Motley Fool
# ..           ...                  ...
# 252   Xylem Inc.        GlobeNewswire
# 253   Xylem Inc.        GlobeNewswire
# 254  Yum! Brands  Yahoo Entertainment
# 255  Yum! Brands   Marketscreener.com
# 256  Yum! Brands             Truthout
#
#                                                 Author  \
# 0                                           Steve Rose
# 1               newsfeedback@fool.com (Keith Speights)
# 2    Trefis Team, Contributor, \n Trefis Team, Cont...
# 3                   newsfeedback@fool.com (Lee Samaha)
# 4    newsfeedback@fool.com (Daniel Foelber, Scott L...
# ..                                                 ...
# 252                                   Halper Sadeh LLC
# ...

# %%
from google.colab import files

df_news_updated.to_csv('df_news_updated.csv')
files.download('df_news_updated.csv')

# %%
df_updated = df.Security.unique()[499:len(symbol_list)]

# %%
news_dict5 = {}
news_dict5['Company'] = []
news_dict5['Source'] = []
news_dict5['Author'] = []
news_dict5['Title'] = []
news_dict5['URL'] = []
news_dict5['Publish_Date'] = []

# %%
# %%time
for company in df_updated:
  print('company', company)
  phrase = '{} stock'.format(company)
  newsapi = NewsApiClient(api_key='e7aed7364414473daa561f9b8f279fbd')
  my_date = date.today() - timedelta(days = 7)
  articles = newsapi.get_everything(q=phrase,
                                  from_param = my_date.isoformat(),
                                  language="en",
                                  sort_by="relevancy",
                                  page_size = 3)

  for i in range(len(articles['articles'])):
    news_dict5['Company'].append(company)
    news_dict5['Source'].append(articles['articles'][i]['source']['name'])
    news_dict5['Author'].append(articles['articles'][i]['author'])
    news_dict5['Title'].append(articles['articles'][i]['title'])
    news_dict5['URL'].append(articles['articles'][i]['url'])
    news_dict5['Publish_Date'].append(articles['articles'][i]['publishedAt'])
# Out:
# company Zebra Technologies
# company Zimmer Biomet
# company Zions Bancorporation
# company Zoetis
# CPU times: user 76 ms, sys: 3.97 ms, total: 80 ms
# Wall time: 991 ms

# %%
df_news_updated1 = pd.concat([df_news_updated, df_news4])

# %%
#df_news_updated = pd.concat([df_news,df_news2, df_news3, df_news4, df_news5])
df_news_updated1
# Out:
#                  Company                        Source  \
# 0                     3M                  The Guardian
# 1                     3M                   Motley Fool
# 2                     3M                        Forbes
# 3                     3M                   Motley Fool
# 4                     3M                   Motley Fool
# ..                   ...                           ...
# 7   Zions Bancorporation                   News.com.au
# 8   Zions Bancorporation  International Business Times
# 9                 Zoetis                   Motley Fool
# 10                Zoetis            Marketscreener.com
# 11                Zoetis                   Motley Fool
#
#                                                Author  \
# 0                                          Steve Rose
# 1              newsfeedback@fool.com (Keith Speights)
# 2   Trefis Team, Contributor, \n Trefis Team, Cont...
# 3                  newsfeedback@fool.com (Lee Samaha)
# ...

# %%
from google.colab import files

df_news_updated1.to_csv('df_news_updated1.csv')
files.download('df_news_updated1.csv')
